# %%
import math

# %%
def doc_input(ten_file):
    inp = open(ten_file, "r")
    M = inp.read()
    return M

M = doc_input("input.txt")
print("bản rõ M là: ", M)
# Out:
# bản rõ M là:  fhfhgfhf gjgj

# %%
M_dec = []
M_bin = []
for i in M:
    if ord(i) > 255:
        M_dec.append(ord(i) % 255)
        M_i = bin(ord(i) % 255)
    else:
        M_dec.append(ord(i))
        M_i = bin(ord(i))
    M_i = M_i[2:]
    for j in range(8 - len(M_i)):
        M_i = "0" + M_i
    M_bin.append(M_i)
print("\n============================")
print("CHUYỂN SANG HỆ NHỊ PHÂN: ")
for i in range(int(len(M_bin) / 8)):
    print(M_bin[8*i: 8*i + 8])
print(M_bin[8*int(len(M_bin)/8):])
len_M = len(M_bin) * 8
print("\n============================")
print("CHIỀU DÀI BIT: ", len_M)
for i in range(len(M_bin)):
    if len(M_bin[i]) > 8:
        print(i)
        print(M_dec[i])
# Out:
# ============================
# CHUYỂN SANG HỆ NHỊ PHÂN:
# ['01100110', '01101000', '01100110', '01101000', '01100111', '01100110', '01101000', '01100110']
# ['00100000', '01100111', '01101010', '01100111', '01101010']
#
# ============================
# CHIỀU DÀI BIT:  104

# %%
M_bin.append("10000000")
if 512 - len_M % 512 > 64:
    for i in range(1, int((512 - len_M % 512 - 64) / 8)):
        M_bin.append("00000000")
else:
    for i in range(1, int((512 + len_M % 512 - 64) / 8)):
        M_bin.append("00000000")
        
length = bin(len_M)
length = length[2:]
for j in range(64 - len(length)):
    length = "0" + length
for i in range(8):
    M_bin.append(length[8*i : 8*i + 8])

print("Nối 10... cho đến khi số bit là bội số của 512 - 64 bit:")
for i in range(int(len(M_bin) / 8)):
    print(M_bin[8*i: 8*i + 8])
# Out:
# Nối 10... cho đến khi số bit là bội số của 512 - 64 bit:
# ['01100110', '01101000', '01100110', '01101000', '01100111', '01100110', '01101000', '01100110']
# ['00100000', '01100111', '01101010', '01100111', '01101010', '10000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '01101000']

# %%
M_len = len(M_bin)
M_block = []
for i in range(int(M_len / 64)):
    M_block.append(M_bin[64*i : 64*i + 64])
for i in range(len(M_block)):
    print("khối thứ {}:".format(i + 1))
    for j in range(8):
        print(M_block[i][8*j: 8*j + 8])
M_block_use = []
M_all = ""
for i in range(len(M_block)):
    for j in M_block[i]:
        M_all = M_all + j
    M_block_use.append(M_all)
    M_all = ""
# Out:
# khối thứ 1:
# ['01100110', '01101000', '01100110', '01101000', '01100111', '01100110', '01101000', '01100110']
# ['00100000', '01100111', '01101010', '01100111', '01101010', '10000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
# ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '01101000']

# %%
a = "01234567"
b = "89abcdef"
c = "fedbca98"
d = "76543210"

print("============================")
print("GIÁ TRỊ KHỞI TẠO CỦA BỘ NHỚ ĐỆM:\n")
print("a = ", a)
print("b = ", b)
print("c = ", c)
print("d = ", d)

a = int(a, 16)
b = int(b, 16)
c = int(c, 16)
d = int(d, 16)
# Out:
# ============================
# GIÁ TRỊ KHỞI TẠO CỦA BỘ NHỚ ĐỆM:
#
# a =  01234567
# b =  89abcdef
# c =  fedbca98
# d =  76543210

# %%
def message_schedule(block):
    # Chia block thành các chunk 32-bit
    chunk_size = 32  # Kích thước chunk là 32-bit
    num_chunks = 16  # Số lượng chunk trong message schedule

    # Chia chuỗi thành các chunk 32-bit
    chunks = [block[i:i+chunk_size] for i in range(0, len(block), chunk_size)]
    print("GIÁ TRỊ CỦA W_i ĐẦU TIÊN SAU KHI CHIA CÁC KHỐI:")
    for i in range(16):
        print("w[{}] = {}".format(i, chunks[i]))

    # Chuyển đổi từng chunk thành số nguyên 32-bit
    w = [0] * num_chunks
    for i in range(num_chunks):
        w[i] = int(chunks[i], 2)
    
    for i in range(3):
        for j in range(16):
            w.append(w[j])
    
    return w

# %%
def f_MD5(x, y, z, i):
    if i >=0 and i <=15:
        return (x & y) | ((15+ ~x) & z)
    elif i >=16 and i <= 31:
        return (z & x) | ((15+ ~z) & y)
    elif i >= 32 and i <=48:
        return x ^ y ^ z
    else:
        return y ^ (x | (15 + ~z))

def ROTL(t, i):
    s = [7, 12, 17, 22] * 4 + [5, 9, 14, 20] * 4 + [4, 11, 16, 23] * 4 + [6, 10, 15, 21] * 4
    steps = s[i]
    t0 = str(bin(t))
    t0 = t0[2:]
    steps = steps % len(t0)
    t1 = t0[0: steps]
    t2 = t0[steps: ]
    return int(t2 + t1, 2)

def MD5(a, b, c, d, W, K):
    a_unit = a
    b_unit = b
    c_unit = c
    d_unit = d

    a1 = a
    b1 = b
    c1 = c
    d1 = d
    for i in range(64):
        a0 = a1
        b0 = b1
        c0 = c1
        d0 = d1

        c1 = b0
        d1 = c0
        a1 = d0
        t = (((a0 + f_MD5(b0, c0, d0, i)) % 2**32 + W[i]) % 2**32 + K[i]) % 2**32
        b1 = (b0 + ROTL(t, i)) % 2**32
    
        print("-----------------------------")
        print("LẦN LẶP THỨ {}:".format(i + 1))  
        print("a = ", dec_to_hex(a1))
        print("b = ", dec_to_hex(b1))
        print("c = ", dec_to_hex(c1))
        print("d = ", dec_to_hex(d1))
    
    a1 = a1 + a_unit
    b1 = b1 + b_unit
    c1 = c1 + c_unit
    d1 = d1 + d_unit
    return a1, b1, c1, d1

def dec_to_hex(a):
    a0 = str(hex(a))
    a0 = a0[2:]
    for i in range(8 - len(a0)):
        a0 = "0" + a0
    return a0

# %%
def MD5_main(M_block_use, a, b, c, d):
    a1 = a
    b1 = b
    c1 = c
    d1 = d

    K = []
    for i in range(64):
        K.append(int(2**32 * abs(math.sin(i))))
    
    print("\n=========================================")
    print("GIÁ TRỊ CỦA K_i:")
    for i in range(64):
        print("K[{}] = {}".format(i, bin(K[i])))
    for i in range(len(M_block_use)):
        print("==========================================================")
        print("==========================================================")
        print("KHỐI THỨ {}:".format(i + 1))
        W = message_schedule(M_block_use[i])
        a0 = a1
        b0 = b1
        c0 = c1
        d0 = d1        
        a1, b1, c1, d1 = MD5(a0, b0, c0, d0, W, K)
        a1 = (a0 + a1) % 2**32
        b1 = (b0 + b1) % 2**32
        c1 = (c0 + c1) % 2**32
        d1 = (d0 + d1) % 2**32
        print("=========================================")
        print("GIÁ TRỊ H_i SAU KHI XỬ LÝ KHỐI THỨ {}:".format(i + 1))
        print("a = ", dec_to_hex(a1))
        print("b = ", dec_to_hex(b1))
        print("c = ", dec_to_hex(c1))
        print("d = ", dec_to_hex(d1))
        print("H[{}] = {}".format(i + 1, dec_to_hex(a1) + dec_to_hex(b1) + dec_to_hex(c1) + dec_to_hex(d1)))
    
    a2 = dec_to_hex(a1)
    b2 = dec_to_hex(b1)
    c2 = dec_to_hex(c1)
    d2 = dec_to_hex(d1)
    print("\n=========================================")
    print("GIÁ TRỊ BỘ ĐỆM H_i SAU KHI XỬ LÝ:")
    return a2 + b2 + c2 + d2

# %%
print("THỰC HIỆN THUẬT TOÁN MD5:")
result = MD5_main(M_block_use, a, b, c, d)
# Out:
# THỰC HIỆN THUẬT TOÁN MD5:
#
# =========================================
# GIÁ TRỊ CỦA K_i:
# K[0] = 0b0
# K[1] = 0b11010111011010101010010001111000
# K[2] = 0b11101000110001111011011101010110
# K[3] = 0b100100001000000111000011011011
# K[4] = 0b11000001101111011100111011101110
# K[5] = 0b11110101011111000000111110101111
# K[6] = 0b1000111100001111100011000101010
# K[7] = 0b10101000001100000100011000010011
# K[8] = 0b11111101010001101001010100000001
# K[9] = 0b1101001100000001001100011011000
# K[10] = 0b10001011010001001111011110101111
# K[11] = 0b11111111111111110101101110110001
# K[12] = 0b10001001010111001101011110111110
# K[13] = 0b1101011100100000001000100100010
# K[14] = 0b11111101100110000111000110010011
# K[15] = 0b10100110011110010100001110001110
# K[16] = 0b1001001101101000000100000100001
# K[17] = 0b11110110000111100010010101100010
# K[18] = 0b11000000010000001011001101000000
# K[19] = 0b100110010111100101101001010001
# K[20] = 0b11101001101101101100011110101010
# K[21] = 0b11010110001011110001000001011101
# K[22] = 0b10010001000001010001010011
# K[23] = 0b11011000101000011110011010000001
# K[24] = 0b11100111110100111111101111001000
# K[25] = 0b100001111000011100110111100110
# K[26] = 0b11000011001101110000011111010110
# K[27] = 0b11110100110101010000110110000111
# K[28] = 0b1000101010110100001010011101101
# K[29] = 0b10101001111000111110100100000101
# K[30] = 0b11111100111011111010001111111000
# K[31] = 0b1100111011011110000001011011001
# K[32] = 0b10001101001010100100110010001010
# K[33] = 0b11111111111110100011100101000010
# K[34] = 0b10000111011100011111011010000001
# K[35] = 0b1101101100111010110000100100010
# K[36] = 0b11111101111001010011100000001100
# K[37] = 0b10100100101111101110101001000100
# K[38] = 0b1001011110111101100111110101001
# K[39] = 0b11110110101110110100101101100000
# K[40] = 0b10111110101111111011110001110000
# K[41] = 0b101000100110110111111011000110
# K[42] = 0b11101010101000010010011111111010
# K[43] = 0b11010100111011110011000010000101
# K[44] = 0b100100010000001110100000101
# K[45] = 0b11011001110101001101000000111001
# K[46] = 0b11100110110110111001100111100101
# K[47] = 0b11111101000100111110011111000
# K[48] = 0b11000100101011000101011001100101
# K[49] = 0b11110100001010010010001001000100
# K[50] = 0b1000011001010101111111110010111
# K[51] = 0b10101011100101000010001110100111
# K[52] = 0b11111100100100111010000000111001
# K[53] = 0b1100101010110110101100111000011
# K[54] = 0b10001111000011001100110010010010
# K[55] = 0b11111111111011111111010001111101
# K[56] = 0b10000101100001000101110111010001
# K[57] = 0b1101111101010000111111001001111
# K[58] = 0b11111110001011001110011011100000
# K[59] = 0b10100011000000010100001100010100
# K[60] = 0b1001110000010000001000110100001
# K[61] = 0b11110111010100110111111010000010
# K[62] = 0b10111101001110101111001000110101
# K[63] = 0b101010110101111101001010111011
# ==========================================================
# ==========================================================
# KHỐI THỨ 1:
# GIÁ TRỊ CỦA W_i ĐẦU TIÊN SAU KHI CHIA CÁC KHỐI:
# w[0] = 01100110011010000110011001101000
# w[1] = 01100111011001100110100001100110
# w[2] = 00100000011001110110101001100111
# w[3] = 01101010100000000000000000000000
# w[4] = 00000000000000000000000000000000
# w[5] = 00000000000000000000000000000000
# w[6] = 00000000000000000000000000000000
# w[7] = 00000000000000000000000000000000
# w[8] = 00000000000000000000000000000000
# w[9] = 00000000000000000000000000000000
# w[10] = 00000000000000000000000000000000
# w[11] = 00000000000000000000000000000000
# w[12] = 00000000000000000000000000000000
# w[13] = 00000000000000000000000000000000
# w[14] = 00000000000000000000000000000000
# w[15] = 00000000000000000000000001101000
# -----------------------------
# LẦN LẶP THỨ 1:
# a =  76543210
# b =  bf7f01d5
# c =  89abcdef
# d =  fedbca98
# -----------------------------
# LẦN LẶP THỨ 2:
# a =  fedbca98
# b =  d02bc1af
# c =  bf7f01d5
# d =  89abcdef
# -----------------------------
# LẦN LẶP THỨ 3:
# a =  89abcdef
# b =  c475051a
# c =  d02bc1af
# d =  bf7f01d5
# -----------------------------
# LẦN LẶP THỨ 4:
# a =  bf7f01d5
# b =  ce9bf39b
# c =  c475051a
# d =  d02bc1af
# -----------------------------
# LẦN LẶP THỨ 5:
# a =  d02bc1af
# b =  0584f2f0
# c =  ce9bf39b
# d =  c475051a
# -----------------------------
# LẦN LẶP THỨ 6:
# a =  c475051a
# b =  a2147b99
# c =  0584f2f0
# d =  ce9bf39b
# -----------------------------
# LẦN LẶP THỨ 7:
# a =  ce9bf39b
# b =  1dbfddcb
# c =  a2147b99
# d =  0584f2f0
# -----------------------------
# LẦN LẶP THỨ 8:
# a =  0584f2f0
# b =  7bbb4e25
# c =  1dbfddcb
# d =  a2147b99
# -----------------------------
# LẦN LẶP THỨ 9:
# a =  a2147b99
# b =  c13e0b73
# c =  7bbb4e25
# d =  1dbfddcb
# -----------------------------
# LẦN LẶP THỨ 10:
# a =  1dbfddcb
# b =  d06fd89d
# c =  c13e0b73
# d =  7bbb4e25
# -----------------------------
# LẦN LẶP THỨ 11:
# a =  7bbb4e25
# b =  97c70222
# c =  d06fd89d
# d =  c13e0b73
# -----------------------------
# LẦN LẶP THỨ 12:
# a =  c13e0b73
# b =  e56d1efb
# c =  97c70222
# d =  d06fd89d
# -----------------------------
# LẦN LẶP THỨ 13:
# a =  d06fd89d
# b =  d6bfd16a
# c =  e56d1efb
# d =  97c70222
# -----------------------------
# LẦN LẶP THỨ 14:
# a =  97c70222
# b =  d8826cd1
# c =  d6bfd16a
# d =  e56d1efb
# -----------------------------
# LẦN LẶP THỨ 15:
# a =  e56d1efb
# b =  64df836e
# c =  d8826cd1
# d =  d6bfd16a
# -----------------------------
# LẦN LẶP THỨ 16:
# a =  d6bfd16a
# b =  b94ec7c7
# c =  64df836e
# d =  d8826cd1
# -----------------------------
# LẦN LẶP THỨ 17:
# a =  d8826cd1
# b =  20cfc3d7
# c =  b94ec7c7
# d =  64df836e
# -----------------------------
# LẦN LẶP THỨ 18:
# a =  64df836e
# b =  ce5483b6
# c =  20cfc3d7
# d =  b94ec7c7
# -----------------------------
# LẦN LẶP THỨ 19:
# a =  b94ec7c7
# b =  178bb749
# c =  ce5483b6
# d =  20cfc3d7
# -----------------------------
# LẦN LẶP THỨ 20:
# a =  20cfc3d7
# b =  30881b9b
# c =  178bb749
# d =  ce5483b6
# -----------------------------
# LẦN LẶP THỨ 21:
# a =  ce5483b6
# b =  32c08717
# c =  30881b9b
# d =  178bb749
# -----------------------------
# LẦN LẶP THỨ 22:
# a =  178bb749
# b =  3b07b0c5
# c =  32c08717
# d =  30881b9b
# -----------------------------
# LẦN LẶP THỨ 23:
# a =  30881b9b
# b =  531396cd
# c =  3b07b0c5
# d =  32c08717
# -----------------------------
# LẦN LẶP THỨ 24:
# a =  32c08717
# b =  612ca33b
# c =  531396cd
# d =  3b07b0c5
# -----------------------------
# LẦN LẶP THỨ 25:
# a =  3b07b0c5
# b =  d651c859
# c =  612ca33b
# d =  531396cd
# -----------------------------
# LẦN LẶP THỨ 26:
# a =  531396cd
# b =  2491b1f7
# c =  d651c859
# d =  612ca33b
# -----------------------------
# LẦN LẶP THỨ 27:
# a =  612ca33b
# b =  4697651e
# c =  2491b1f7
# d =  d651c859
# -----------------------------
# LẦN LẶP THỨ 28:
# a =  d651c859
# b =  6e932e50
# c =  4697651e
# d =  2491b1f7
# -----------------------------
# LẦN LẶP THỨ 29:
# a =  2491b1f7
# b =  b6fb61e0
# c =  6e932e50
# d =  4697651e
# -----------------------------
# LẦN LẶP THỨ 30:
# a =  4697651e
# b =  c907fbda
# c =  b6fb61e0
# d =  6e932e50
# -----------------------------
# LẦN LẶP THỨ 31:
# a =  6e932e50
# b =  e649b3be
# c =  c907fbda
# d =  b6fb61e0
# -----------------------------
# LẦN LẶP THỨ 32:
# a =  b6fb61e0
# b =  ba0608bc
# c =  e649b3be
# d =  c907fbda
# -----------------------------
# LẦN LẶP THỨ 33:
# a =  c907fbda
# b =  f76b636b
# c =  ba0608bc
# d =  e649b3be
# -----------------------------
# LẦN LẶP THỨ 34:
# a =  e649b3be
# b =  631ac247
# c =  f76b636b
# d =  ba0608bc
# -----------------------------
# LẦN LẶP THỨ 35:
# a =  ba0608bc
# b =  21517ee1
# c =  631ac247
# d =  f76b636b
# -----------------------------
# LẦN LẶP THỨ 36:
# a =  f76b636b
# b =  7718c32a
# c =  21517ee1
# d =  631ac247
# -----------------------------
# LẦN LẶP THỨ 37:
# a =  631ac247
# b =  a15a7364
# c =  7718c32a
# d =  21517ee1
# -----------------------------
# LẦN LẶP THỨ 38:
# a =  21517ee1
# b =  0d344b5b
# c =  a15a7364
# d =  7718c32a
# -----------------------------
# LẦN LẶP THỨ 39:
# a =  7718c32a
# b =  56d3dca9
# c =  0d344b5b
# d =  a15a7364
# -----------------------------
# LẦN LẶP THỨ 40:
# a =  a15a7364
# b =  673c6e9c
# c =  56d3dca9
# d =  0d344b5b
# -----------------------------
# LẦN LẶP THỨ 41:
# a =  0d344b5b
# b =  369f02c5
# c =  673c6e9c
# d =  56d3dca9
# -----------------------------
# LẦN LẶP THỨ 42:
# a =  56d3dca9
# b =  3a77926d
# c =  369f02c5
# d =  673c6e9c
# -----------------------------
# LẦN LẶP THỨ 43:
# a =  673c6e9c
# b =  3d4f3fb7
# c =  3a77926d
# d =  369f02c5
# -----------------------------
# LẦN LẶP THỨ 44:
# a =  369f02c5
# b =  5dbd1305
# c =  3d4f3fb7
# d =  3a77926d
# -----------------------------
# LẦN LẶP THỨ 45:
# a =  3a77926d
# b =  b88afd9e
# c =  5dbd1305
# d =  3d4f3fb7
# -----------------------------
# LẦN LẶP THỨ 46:
# a =  3d4f3fb7
# b =  e2299504
# c =  b88afd9e
# d =  5dbd1305
# -----------------------------
# LẦN LẶP THỨ 47:
# a =  5dbd1305
# b =  f7654229
# c =  e2299504
# d =  b88afd9e
# -----------------------------
# LẦN LẶP THỨ 48:
# a =  b88afd9e
# b =  03bb8d9f
# c =  f7654229
# d =  e2299504
# -----------------------------
# LẦN LẶP THỨ 49:
# a =  e2299504
# b =  a980d51d
# c =  03bb8d9f
# d =  f7654229
# -----------------------------
# LẦN LẶP THỨ 50:
# a =  f7654229
# b =  13c118bc
# c =  a980d51d
# d =  03bb8d9f
# -----------------------------
# LẦN LẶP THỨ 51:
# a =  03bb8d9f
# b =  c1c5f15a
# c =  13c118bc
# d =  a980d51d
# -----------------------------
# LẦN LẶP THỨ 52:
# a =  a980d51d
# b =  5381b32c
# c =  c1c5f15a
# d =  13c118bc
# -----------------------------
# LẦN LẶP THỨ 53:
# a =  13c118bc
# b =  772091e5
# c =  5381b32c
# d =  c1c5f15a
# -----------------------------
# LẦN LẶP THỨ 54:
# a =  c1c5f15a
# b =  d59df47c
# c =  772091e5
# d =  5381b32c
# -----------------------------
# LẦN LẶP THỨ 55:
# a =  5381b32c
# b =  eb21e255
# c =  d59df47c
# d =  772091e5
# -----------------------------
# LẦN LẶP THỨ 56:
# a =  772091e5
# b =  20741ccd
# c =  eb21e255
# d =  d59df47c
# -----------------------------
# LẦN LẶP THỨ 57:
# a =  d59df47c
# b =  9faf6cfc
# c =  20741ccd
# d =  eb21e255
# -----------------------------
# LẦN LẶP THỨ 58:
# a =  eb21e255
# b =  a6ff5b64
# c =  9faf6cfc
# d =  20741ccd
# -----------------------------
# LẦN LẶP THỨ 59:
# a =  20741ccd
# b =  d766a503
# c =  a6ff5b64
# d =  9faf6cfc
# -----------------------------
# LẦN LẶP THỨ 60:
# a =  9faf6cfc
# b =  e27ba44f
# c =  d766a503
# d =  a6ff5b64
# -----------------------------
# LẦN LẶP THỨ 61:
# a =  a6ff5b64
# b =  f79bc6c2
# c =  e27ba44f
# d =  d766a503
# -----------------------------
# LẦN LẶP THỨ 62:
# a =  d766a503
# b =  c4f171b2
# c =  f79bc6c2
# d =  e27ba44f
# -----------------------------
# LẦN LẶP THỨ 63:
# a =  e27ba44f
# b =  ef4c513a
# c =  c4f171b2
# d =  f79bc6c2
# -----------------------------
# LẦN LẶP THỨ 64:
# a =  f79bc6c2
# b =  f728c97a
# c =  ef4c513a
# d =  c4f171b2
# =========================================
# GIÁ TRỊ H_i SAU KHI XỬ LÝ KHỐI THỨ 1:
# a =  f9e25190
# b =  0a806558
# c =  ed03e66a
# d =  b199d5d2
# H[1] = f9e251900a806558ed03e66ab199d5d2
#
# =========================================
# GIÁ TRỊ BỘ ĐỆM H_i SAU KHI XỬ LÝ:

# %%
print("\n=========================================")
print("KẾT QUẢ CUỐI CÙNG:")
print("MD5 = ", result)
# Out:
# =========================================
# KẾT QUẢ CUỐI CÙNG:
# MD5 =  f9e251900a806558ed03e66ab199d5d2
